# %% [markdown]
# # Week 3 Day 4 Lab
#
# ### Problem 1
# We are going to make a social network. This can be real or made up. Up to you!
# 1. Add nodes representing people
# 2. Add edges if these people talk
# 3. Make the edges bigger if they are good friends and smaller if they are just acquaintances
# 4. Make the nodes size correspond to height
# 5. Make the node color correspond to hair color (i.e. if hair is brunette, the node is brown)
#
#
# Make sure your final plot has:
# - a title
# - the names of the people displayed
# - color
# - is legible and presentable
# - an appropriate sizing

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
G.add_node("Ube", size=10, color="purple") #Siamese
G.add_node("Yam", size=12, color="orange") #Calico
G.add_node("Yukon", size=14, color="gold") #Orange
G.add_node("Chester", size=13, color="blue") #Tuxedo
G.add_edge("Ube", "Yam", weight=5)
G.add_edge("Yam", "Yukon", weight=5)
G.add_edge("Ube", "Yukon", weight=3)
G.add_edge("Yukon", "Chester", weight=2)
pos = nx.spring_layout(G, seed=42)
node_sizes = [G.nodes[n]["size"] * 300 for n in G.nodes()]
node_colors = [G.nodes[n]["color"] for n in G.nodes()]
edge_widths = [G[u][v]["weight"] for u, v in G.edges()]
plt.figure(figsize=(7,6))
nx.draw_networkx_nodes(
    G, pos,
    node_size=node_sizes,
    node_color=node_colors,
    edgecolors="black"
)
nx.draw_networkx_edges(
    G, pos,
    width=edge_widths
)
nx.draw_networkx_labels(
    G, pos,
    font_size=11,
    font_weight="bold"
)
plt.title("My cats and their weird cousin, 'Chester'")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Problem 2
#
# For the dolphin social network:
# 1. Import the data
# 2. Draw the network
# 3. Use as many `networkx` parameters as possible (that is, in `nx.draw()`, add all the parameters: `node_size`, `node_color`, etc.) such that the network is still presentable and understandable
#
# You can find some information about `nx.draw()` here: https://networkx.org/documentation/stable/reference/generated/networkx.drawing.nx_pylab.draw.html#networkx.drawing.nx_pylab.draw .

# %%
import pandas as pd

df = pd.read_csv("DolphinNetwork.csv")
print(df.head())
print(df.columns)
# Out:
#     Source  Target
# 0   Double     CCL
# 1  Feather    DN16
# 2  Feather    DN21
# 3     Fish    Beak
# 4     Fish  Bumper
# Index(['Source', 'Target'], dtype='object')

# %%
import networkx as nx
import matplotlib.pyplot as plt
import os
print(os.getcwd())
print(os.listdir())
G = nx.read_gml("DolphinNetwork.csv")
pos = nx.spring_layout(G, seed=42)
plt.figure(figsize=(12,10))
nx.draw(
    G,
    pos,
    with_labels=True,
    node_size=400,
    node_color="skyblue",
    edge_color="grey",
    width=1.5,
    font_size=8,
    font_color="black",
    font_weight="bold",
    alpha=0.9
)
plt.title("Dolphin Social Network")
plt.show()
# Out:
# /home/db0e0fa7-67ef-4ae9-a53f-f448cb0fa58d
# ['.gitconfig', 'Untitled3.ipynb', '.config', '.pythonstartup.py', 'week1-lab3.ipynb', 'Week 3 Day 1 Lab.ipynb', '.cache', 'week1-lab4.ipynb', '.anaconda', 'week2-lab1.ipynb', '.vimrc', 'Week 3 Day 2 Lab.ipynb', 'Week 2 Day 3 Lab.ipynb', 'README.ipynb', '.profile', '.ipython', 'DolphinNetwork.csv', 'Week 3 Day 3 Lab.ipynb', 'Week 2 Day 2 Lab.ipynb', 'week1-lab3.py', '.jupyter', '.bashrc', 'week1-lab5.ipynb', 'Homework 1.ipynb', '.ipynb_checkpoints', 'Week 3 Day 4 Lab.ipynb', 'WA_County_Boundaries.cpg', 'anaconda_projects', '.npm', '.local', 'Untitled4.ipynb', 'Notes.ipynb', '.conda', '.virtualenvs']
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_7746/860851957.py", line 6, in <cell line: 6>
#     G = nx.read_gml("DolphinNetwork.csv")
#   File "<class 'networkx.utils.decorators.argmap'> compilation 13", line 5, in argmap_read_gml_9
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/networkx/readwrite/gml.py", line 195, in read_gml
#     G = parse_gml_lines(filter_lines(path), label, destringizer)
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/networkx/readwrite/gml.py", line 433, in parse_gml_lines
#     graph = parse_graph()
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/networkx/readwrite/gml.py", line 422, in parse_graph
#     curr_token, dct = parse_kv(next(tokens))
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/networkx/readwrite/gml.py", line 354, in parse_kv
#     curr_token = next(tokens)
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/networkx/readwrite/gml.py", line 321, in tokenize
#     raise NetworkXError(m)
# networkx.exception.NetworkXError: cannot tokenize ,Target at (1, 7)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 1982, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
