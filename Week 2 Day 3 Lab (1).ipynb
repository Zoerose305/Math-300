# %% [markdown]
# # Week 2 Day 3 Lab

# %% [markdown]
# ## Problem 1
# Import `numpy`, `math`, and `sympy`.

# %%
import math

# %%
import sympy as sp

# %%
import numpy as np

# %% [markdown]
# ## Problem 2
#
# 1. Write a recursive function `factorial()` that takes in a natural number `n` and computes $n!=n(n-1)(n-2)\cdots3\cdot2\cdot 1$.
# 2. Use `%timeit` to determine how fast your function calculates `factorial(150)`.
# 3. Use `%timeit` to calculate how fast `math.factorial()` calculates the same quantity.
# 4. Were there any differences between the two methods?

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n-1)
n = int(input("Enter a natural number: "))
print("Factorial of", n, "is", factorial(n))
# Out:
# Enter a natural number:  5
# Factorial of 5 is 120

# %%
# %timeit math.factorial(150)
# Out:
# 6.77 µs ± 476 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    result = 1
    for i in range(2, n + 1):
        result *= i
# %timeit factorial(150)
# Out:
# 11.5 µs ± 715 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# The second option took more effort to input and took longer to run.

# %% [markdown]
# ## Problem 3
# Recall for a quadratic equation of the form
# $$ax^2 + bx + c = 0
# $$
#
# The solutions are given by the <i>quadratic formula</i>:
#
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# 1. Write a function `quadratic()` that calculates the two roots given by the quadratic formula only if they are real.
# 2. Use `%timeit` to determine how fast your function calculates the roots for $437x^2 - 915x + 478 = 0$.
# 3. Use `%timeit` to calculate how fast `sp.solve()` calculates the same quantities.
# 4. Were there any differences between the two methods?

# %%
import math
def quadratic(a, b, c):
    discriminant = b**2 - 4*a*c
    if discriminant <0:
        return "no real roots"
    else:
        root1 = (-b + math.sqrt(discriminant)) / (2*a)
        root2 = (-b - math.sqrt(discriminant)) / (2*a)
        return root1, root2
# %timeit quadratic(437, 915, 478)
# Out:
# 943 ns ± 22.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
import sympy as sp
# %timeit sp.solve(437, 915, 478)
# Out:
# 207 µs ± 15.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# Using sympy took significantly less time and takes less effort to import code.

# %% [markdown]
# ## Problem 4
#
# For each of the following functions, use `sympy` calculate the first derivative, the second derivative, and the integral (all with respect to $x$):
#
# 1. $f(x)=x$
# 2. $f(x)=6x^{-1/2}$
# 3. $f(x)=\pi\sqrt{x}+x^5+7$
# 4. $f(x)=x(2x-5)(3+\tan(x))$

# %%
import sympy as sp
x = sp.Symbol('x')

# %%
import sympy as sp
x = sp.Symbol('x')

f == x 
print("first derivative:")
print(sp.diff(f,x))

print("\nSecond derivative:")
print(sp.diff(f,x, 2))
      
print("\nIntegral:")
print(sp.integrate(f,x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 4>()
#       1 import sympy as sp
#       2 x = sp.Symbol('x')
# ----> 4 f == x
#       5 print("first derivative:")
#       6 print(sp.diff(f,x))
#
# NameError: name 'f' is not defined

# %% [markdown]
# I am unsure how to fix this

# %% [markdown]
# ## Problem 5
#
# From yesterday, we calculated <i>numerically</i> what the derivative of $\sin(x)$ is.
# 1. Using sympy, calculate derivative at 0.
# 2. Using sympy, evaluate the limit definition of the derivative for $f(x)=\sin(x)$:
# $$f'(x)=\lim_{h\to0}\frac{f(x+h)-f(x)}{h}
# $$

# %%
import sympy as sp
x = sp.symbols('x')
f = sin(x)
derivative_at_0 = sp.diff(f,x).subs(x,0)
print(derivative_at_0)
h = sp.symbols('h')
limit_definition = sp.limit((f.subs(x,h) - f.subs(x,0))/h, h, 0)
print(limit_definition)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 3>()
#       1 import sympy as sp
#       2 x = sp.symbols('x')
# ----> 3 f = sin(x)
#       4 derivative_at_0 = sp.diff(f,x).subs(x,0)
#       5 print(derivative_at_0)
#
# NameError: name 'sin' is not defined
