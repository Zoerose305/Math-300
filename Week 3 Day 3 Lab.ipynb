# %% [markdown]
# # Week 3 Day 3 Lab
#
# ### Problem 1
# 1. Create your own dataframe with at least 3 columns and 4 rows.
# 2. Save the dataframe to a csv file.
# 3. Read the csv back in.
# 4. Plot the data.

# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: pandas in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
Name = [Ube, Yam, Yukon, Chester]
Breed = [Siamese, Calico, Orange, Tuxedo]
Age = [2+ years, 1+ years, 5 months, 2 years]

# %%
import pandas as pd
Name = ['Ube', 'Yam', 'Yukon', 'Chester']
Breed = ['Siamese', 'Calico', 'Orange', 'Tuxedo']
Age = ['2+ years', '1+ years', '5 months', '2 years']
dataframe = pd.DataFrame({
    'Name': Name,
    'Breed': Breed,
    'Age': Age,
})
print(dataframe)
# Out:
#       Name    Breed       Age
# 0      Ube  Siamese  2+ years
# 1      Yam   Calico  1+ years
# 2    Yukon   Orange  5 months
# 3  Chester   Tuxedo   2 years

# %% [markdown]
# ### Problem 2
# ```python
# list1 = [655, 115, 26, 760, 282, 251, 229, 143, 755, 105, 693, 759, 914, 559, 90, 605, 433, 33, 31, 96, 224, 239, 518, 617, 28, 575, 204, 734, 666, 719, 559, 430, 226, 460, 604, 285, 829, 891, 7, 778, 826, 164, 715, 433, 349, 285, 160, 221, 981, 782, 345, 105, 95, 390, 100, 368, 868, 353, 619, 271, 827, 45, 748, 471, 550, 128, 997, 945, 388, 81, 566, 301, 850, 644, 634, 907, 883, 371, 592, 197, 722, 72, 47, 678, 234, 792, 297, 82, 876, 239, 888, 104, 390, 285, 465, 651, 855, 374, 167, 380]
#
# list2 = [364, 215, 687, 274, 719, 960, 700, 664, 74, 624, 651, 176, 547, 747, 251, 168, 474, 389, 277, 948, 656, 705, 571, 225, 702, 333, 864, 787, 795, 58, 235, 842, 33, 825, 324, 411, 275, 68, 217, 936, 966, 581, 898, 736, 323, 218, 672, 512, 406, 906, 937, 659, 470, 147, 272, 143, 253, 763, 575, 552, 270, 765, 599, 439, 920, 598, 409, 371, 225, 142, 522, 506, 94, 774, 49, 882, 113, 157, 643, 164, 812, 697, 433, 611, 66, 395, 391, 611, 480, 542, 258, 995, 567, 882, 966, 12, 697, 739, 118, 699]
#
# list3 = [907, 550, 769, 274, 788, 657, 349, 115, 301, 446, 162, 465, 4, 977, 740, 897, 737, 270, 996, 513, 781, 183, 520, 935, 109, 892, 641, 306, 862, 655, 520, 624, 204, 157, 383, 781, 166, 553, 977, 798, 945, 544, 941, 1, 614, 332, 501, 20, 115, 952, 372, 900, 852, 827, 315, 246, 60, 247, 900, 581, 970, 81, 88, 750, 498, 836, 71, 779, 546, 785, 129, 132, 676, 487, 970, 563, 170, 272, 541, 894, 622, 434, 988, 217, 952, 553, 774, 748, 707, 206, 731, 320, 409, 688, 666, 383, 449, 922, 530, 463]
#
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame({
    "list1": list1,
    "list2": list2,
    "list3": list3,
    "list4": list4,
})
#2
print(df.describe())
#3
print(df.tail())
#4
fig, axes = plt.subplots(2, 2, figsize=(12,10))
df["list1"].plot(ax=axes[0,0], title ="List1")
axes[0,0].set_xlabel("Index")
axes[0,0].set_ylabel("Value")
df["list2"].plot(ax=axes[0,1], color="pink", title="List2")
axes[0,1].set_xlabel("Index")
axes[0,1].set_ylabel("Value")
df["list3"].plot(ax=axes[1,0], color="orange", title="List3")
axes[1,0].set_xlabel("Index")
axes[1,0].set_ylabel("Value")
df["list4"].plot(ax=axes[1,1], color="magenta", title="List4")
axes[1,1].set_xlabel("Index")
axes[1,1].set_ylabel("Value")
plt.tight_layout()
plt.show
# Out:
#             list1       list2       list3       list4
# count  100.000000  100.000000  100.000000  100.000000
# mean   452.800000  503.730000  542.290000  446.650000
# std    288.821395  277.573536  293.385233  292.443602
# min      7.000000   12.000000    1.000000    8.000000
# 25%    216.750000  256.750000  294.250000  195.000000
# 50%    410.000000  532.000000  548.000000  438.000000
# 75%    716.000000  708.500000  782.000000  677.750000
# max    997.000000  995.000000  996.000000  993.000000
#     list1  list2  list3  list4
# 95    651     12    383    243
# 96    855    697    449    171
# 97    374    739    922    417
# 98    167    118    530    498
# 99    380    699    463    493
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Problem 3
# Download the "WA_County_Boundaries" folder from the "Datasets" folder on GitHub.
# - Read the .shp file into Jupyter by using `variable_name = geopandas.read_file("path_to_.shp_file.shp")`
# - Plot the state using `variable_name.plot()`
# - Plot some information about the state by extracting two columns of data.

# %%
# %pip install geopandas
import geopandas as gpd
import matplotlib.pyplot as plt
wa = gpd.read_file("WA_County_Boundaries/WA_County_boundaries.shp")
wa.plot()
plt.title("Washington state boundaries")
plt.show()
print(wa[['JURISDICT_N']])
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: geopandas in ./.local/lib/python3.9/site-packages (1.0.1)
# Requirement already satisfied: pandas>=1.4.0 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: packaging in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from geopandas) (21.3)
# Requirement already satisfied: shapely>=2.0.0 in ./.local/lib/python3.9/site-packages (from geopandas) (2.0.7)
# Requirement already satisfied: pyogrio>=0.7.2 in ./.local/lib/python3.9/site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: numpy>=1.22 in ./.local/lib/python3.9/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyproj>=3.3.0 in ./.local/lib/python3.9/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas) (2021.3)
# Requirement already satisfied: certifi in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from pyogrio>=0.7.2->geopandas) (2021.10.8)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.4.0->geopandas) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages (from packaging->geopandas) (3.0.4)
